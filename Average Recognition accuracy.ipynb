# %%
import matplotlib.pyplot as plt

# Define bit flip levels
bit_flips = list(range(8))

# Average Recognition Accuracy data of Song et.al model
pdf_data = [98.76, 97.85, 97.73, 95.81, 87.04, 82.77, 79.81, 77.15]

# Average Recognition Accuracy data of our model
docx_data = [99.79, 97.25, 93.83, 90.61, 88.07, 85.36, 82.92, 80.35]

# Plotting
plt.figure(figsize=(14, 8))

plt.plot(bit_flips, pdf_data, label='Average recognition accuracy of Song et.al model', linestyle='--')
plt.plot(bit_flips, docx_data, label='Average recognition accuracy of Our model', linestyle='-')

plt.title('Average recognition accuracy comparison of Song et.al model and our model under Bit Flipping Noise')
plt.xlabel('Number of Bit Flips')
plt.ylabel('Average recognition accuracy (%)')
plt.xticks(bit_flips)
plt.xlim(0, 7)
ax.spines['bottom'].set_bounds(0, 7)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
